# %% [markdown]
# # **Data Engineering Module Seminar Session for week 1.**

# %% [markdown]
# Running my first python cell on Google colab

# %%
print("Welcome to Data Engineering Module !")
# Out:
# Welcome to Data Engineering Module !

# %% [markdown]
# Variables and data types

# %%
age = 25            # this is an int data type
pi = 3.14           # this is a float data type
name = "Habeeb"     # this is a string data type
is_student = True   #

# %%
print(f'Welcome to Data Engineering Module, my name is {name}, I am the module leader and I am {age} years old.')
# Out:
# Welcome to Data Engineering Module, my name is Habeeb, I am the module leader and I am 25 years old.

# %%
pip install pandas

# %%
import pandas as pd
data=pd.DataFrame({'A':[1,2,3,]})

# %%
module = 'Data engineering'

# change the engineering in the module to 'science' using str.replace
